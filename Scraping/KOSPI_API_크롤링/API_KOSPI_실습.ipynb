# %% [markdown]
# # 코스피 정보

# %%
import requests
KOSPI_API ="https://api.stock.naver.com/chart/domestic/index/KOSPI?periodType=dayCandle"
response = requests.get(KOSPI_API)
response.status_code
# Out:
# 200

# %%
datas = response.json()
price_info_datas = datas['priceInfos']
price_info_datas[:2]
price_info
# Out:
# [{'localDate': '20221021',
#   'closePrice': 674.48,
#   'openPrice': 678.16,
#   'highPrice': 682.49,
#   'lowPrice': 674.48,
#   'accumulatedTradingVolume': 1034393,
#   'foreignRetentionRate': 0.0},
#  {'localDate': '20221024',
#   'closePrice': 688.5,
#   'openPrice': 686.43,
#   'highPrice': 693.44,
#   'lowPrice': 686.43,
#   'accumulatedTradingVolume': 817958,
#   'foreignRetentionRate': 0.0},
#  {'localDate': '20221025',
#   'closePrice': 688.85,
#   'openPrice': 690.77,
#   'highPrice': 695.95,
#   'lowPrice': 686.21,
#   'accumulatedTradingVolume': 973740,
#   'foreignRetentionRate': 0.0},
#  {'localDate': '20221026',
#   'closePrice': 683.17,
#   'openPrice': 690.67,
#   'highPrice': 691.13,
#   'lowPrice': 683.14,
#   'accumulatedTradingVolume': 963244,
#   'foreignRetentionRate': 0.0},
#  {'localDate': '20221027',
#   'closePrice': 695.09,
#   'openPrice': 686.41,
#   'highPrice': 695.22,
#   'lowPrice': 686.41,
#   'accumulatedTradingVolume': 852166,
# ...

# %%
kospi_df = pd.DataFrame(price_info_datas)
kospi_df
# Out:
#     localDate  closePrice  openPrice  highPrice  lowPrice  \
# 0    20221021     2213.12    2210.59    2224.04   2204.64
# 1    20221024     2236.16    2248.26    2256.67   2229.85
# 2    20221025     2235.07    2237.04    2253.24   2230.75
# 3    20221026     2249.56    2240.70    2258.11   2234.49
# 4    20221027     2288.78    2266.07    2290.56   2262.02
# ..        ...         ...        ...        ...       ...
# 105  20230323     2424.48    2398.27    2424.48   2397.91
# 106  20230324     2414.96    2421.27    2423.76   2399.49
# 107  20230327     2409.22    2423.94    2423.94   2395.97
# 108  20230328     2434.94    2418.69    2434.94   2415.34
# 109  20230329     2443.92    2432.63    2443.95   2428.61
#
#      accumulatedTradingVolume  foreignRetentionRate
# 0                      637486                   0.0
# 1                      444820                   0.0
# 2                      456770                   0.0
# 3                      563441                   0.0
# ...

# %% [markdown]
# # 코스닥 정보 가져오기

# %%
import requests
from bs4 import BeautifulSoup

KOSDAQ_URL ="https://api.stock.naver.com/chart/domestic/index/KOSDAQ?periodType=dayCandle"
response = requests.get(KOSDAQ_URL)
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"code":"KOSDAQ","infoType":"index","periodType":"dayCandle","newlyListed":false,"stockExchangeType":"KRX","hasVolume":true,"decimalUnit":2,"priceInfos":[{"localDate":"20221021","closePrice":674.48,"openPrice":678.16,"highPrice":682.49,"lowPrice":674.48,"accumulatedTradingVolume":1034393,"foreignRetentionRate":0.0},{"localDate":"20221024","closePrice":688.5,"openPrice":686.43,"highPrice":693.44,"lowPrice":686.43,"accumulatedTradingVolume":817958,"foreignRetentionRate":0.0},{"localDate":"20221025","closePrice":688.85,"openPrice":690.77,"highPrice":695.95,"lowPrice":686.21,"accumulatedTradingVolume":973740,"foreignRetentionRate":0.0},{"localDate":"20221026","closePrice":683.17,"openPrice":690.67,"highPrice":691.13,"lowPrice":683.14,"accumulatedTradingVolume":963244,"foreignRetentionRate":0.0},{"localDate":"20221027","closePrice":695.09,"openPrice":686.41,"highPrice":695.22,"lowPrice":686.41,"accumulatedTradingVolume":852166,"foreignRetentionRate":0.0},{"localDate":"20221028","closePr
# ...

# %%
datas = response.json()
datas
# Out:
# {'code': 'KOSDAQ',
#  'infoType': 'index',
#  'periodType': 'dayCandle',
#  'newlyListed': False,
#  'stockExchangeType': 'KRX',
#  'hasVolume': True,
#  'decimalUnit': 2,
#  'priceInfos': [{'localDate': '20221021',
#    'closePrice': 674.48,
#    'openPrice': 678.16,
#    'highPrice': 682.49,
#    'lowPrice': 674.48,
#    'accumulatedTradingVolume': 1034393,
#    'foreignRetentionRate': 0.0},
#   {'localDate': '20221024',
#    'closePrice': 688.5,
#    'openPrice': 686.43,
#    'highPrice': 693.44,
#    'lowPrice': 686.43,
#    'accumulatedTradingVolume': 817958,
#    'foreignRetentionRate': 0.0},
#   {'localDate': '20221025',
#    'closePrice': 688.85,
#    'openPrice': 690.77,
#    'highPrice': 695.95,
#    'lowPrice': 686.21,
#    'accumulatedTradingVolume': 973740,
#    'foreignRetentionRate': 0.0},
#   {'localDate': '20221026',
#    'closePrice': 683.17,
#    'openPrice': 690.67,
#    'highPrice': 691.13,
#    'lowPrice': 683.14,
#    'accumulatedTradingVolume': 963244,
# ...

# %%
price_info =datas['priceInfos']

# %%
import pandas as pd
df_KOSDAQ = pd.DataFrame(price_info)
df_KOSDAQ
# Out:
#     localDate  closePrice  openPrice  highPrice  lowPrice  \
# 0    20221021      674.48     678.16     682.49    674.48
# 1    20221024      688.50     686.43     693.44    686.43
# 2    20221025      688.85     690.77     695.95    686.21
# 3    20221026      683.17     690.67     691.13    683.14
# 4    20221027      695.09     686.41     695.22    686.41
# ..        ...         ...        ...        ...       ...
# 105  20230323      812.19     807.53     824.20    806.40
# 106  20230324      824.11     820.16     824.11    814.07
# 107  20230327      827.69     827.95     829.18    817.81
# 108  20230328      833.51     831.07     833.68    825.40
# 109  20230329      843.94     833.90     843.94    832.44
#
#      accumulatedTradingVolume  foreignRetentionRate
# 0                     1034393                   0.0
# 1                      817958                   0.0
# 2                      973740                   0.0
# 3                      963244                   0.0
# ...

# %% [markdown]
# # 달러 환율 가져오기

# %%
EXCHANGE_RATE_URL ="https://m.stock.naver.com/front-api/v1/chart/pricesByPeriod?category=exchange&reutersCode=FX_USDKRW&chartInfoType=marketindex&scriptChartType=areaYear"
response = requests.get(EXCHANGE_RATE_URL)
data1 = response.json()
data2= data1['result']
USD_rate = data2['priceInfos']
USD_rate
# Out:
# [{'localDate': '20220329',
#   'closePrice': 1219,
#   'openPrice': 0,
#   'highPrice': 1219,
#   'lowPrice': 1219},
#  {'localDate': '20220330',
#   'closePrice': 1211.5,
#   'openPrice': 0,
#   'highPrice': 1211.5,
#   'lowPrice': 1211.5},
#  {'localDate': '20220331',
#   'closePrice': 1213.5,
#   'openPrice': 0,
#   'highPrice': 1213.5,
#   'lowPrice': 1213.5},
#  {'localDate': '20220401',
#   'closePrice': 1220,
#   'openPrice': 0,
#   'highPrice': 1220,
#   'lowPrice': 1220},
#  {'localDate': '20220404',
#   'closePrice': 1216,
#   'openPrice': 0,
#   'highPrice': 1216,
#   'lowPrice': 1216},
#  {'localDate': '20220405',
#   'closePrice': 1214,
#   'openPrice': 0,
#   'highPrice': 1214,
#   'lowPrice': 1214},
#  {'localDate': '20220406',
#   'closePrice': 1218,
#   'openPrice': 0,
#   'highPrice': 1218,
#   'lowPrice': 1218},
#  {'localDate': '20220407',
#   'closePrice': 1220.5,
#   'openPrice': 0,
#   'highPrice': 1220.5,
#   'lowPrice': 1220.5},
#  {'localDate': '20220408',
# ...

# %%
df_USD = pd.DataFrame(USD_rate)
df_USD
# Out:
#     localDate  closePrice  openPrice  highPrice  lowPrice
# 0    20220329      1219.0          0     1219.0    1219.0
# 1    20220330      1211.5          0     1211.5    1211.5
# 2    20220331      1213.5          0     1213.5    1213.5
# 3    20220401      1220.0          0     1220.0    1220.0
# 4    20220404      1216.0          0     1216.0    1216.0
# ..        ...         ...        ...        ...       ...
# 246  20230323      1284.0          0     1284.0    1284.0
# 247  20230324      1300.0          0     1300.0    1300.0
# 248  20230327      1302.0          0     1302.0    1302.0
# 249  20230328      1300.5          0     1300.5    1300.5
# 250  20230329      1302.5          0     1302.5    1302.5
#
# [251 rows x 5 columns]

# %% [markdown]
# # 코스피, 코스닥, 달러환율을 시각화 (2023-01-01~오늘까지)
#  (하나의 캔버스에)

# %% [markdown]
# - 데이터 편집

# %%
df_KOSDAQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   localDate                 110 non-null    object
#  1   closePrice                110 non-null    float64
#  2   openPrice                 110 non-null    float64
#  3   highPrice                 110 non-null    float64
#  4   lowPrice                  110 non-null    float64
#  5   accumulatedTradingVolume  110 non-null    int64
#  6   foreignRetentionRate      110 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 6.1+ KB

# %%
df_KOSDAQ_2023 = df_KOSDAQ[df_KOSDAQ['localDate']>= '20230101']

df_KOSDAQ_2023['localDate']=pd.to_datetime(df_KOSDAQ_2023['localDate'])
df_KOSDAQ_2023
# Out:
# C:\Users\JeeYeon Kim\AppData\Local\Temp\ipykernel_11300\2730312700.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_KOSDAQ_2023['localDate']=pd.to_datetime(df_KOSDAQ_2023['localDate'])
#      localDate  closePrice  openPrice  highPrice  lowPrice  \
# 50  2023-01-02      671.51     683.84     688.77    670.38
# 51  2023-01-03      674.95     672.18     675.75    660.32
# 52  2023-01-04      683.67     670.18     683.67    667.30
# 53  2023-01-05      679.92     685.78     688.35    677.77
# 54  2023-01-06      688.94     677.28     691.17    676.40
# 55  2023-01-09      701.21     695.02     701.21    695.02
# 56  2023-01-10      696.05     700.16     704.60    694.92
# 57  2023-01-11      709.77     701.29     710.29    701.29
# ...

# %%
df_USD_2023 = df_USD[df_USD['localDate']>='20230101']
df_USD_2023['localDate']=pd.to_datetime(df_USD_2023['localDate'])
df_USD_2023
# Out:
# C:\Users\JeeYeon Kim\AppData\Local\Temp\ipykernel_11300\470786382.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_USD_2023['localDate']=pd.to_datetime(df_USD_2023['localDate'])
#      localDate  closePrice  openPrice  highPrice  lowPrice
# 191 2023-01-02      1273.0          0     1273.0    1273.0
# 192 2023-01-03      1276.0          0     1276.0    1276.0
# 193 2023-01-04      1274.0          0     1274.0    1274.0
# 194 2023-01-05      1276.0          0     1276.0    1276.0
# 195 2023-01-06      1260.0          0     1260.0    1260.0
# 196 2023-01-09      1245.0          0     1245.0    1245.0
# 197 2023-01-10      1248.0          0     1248.0    1248.0
# 198 2023-01-11      1250.0          0     1250.0    1250.0
# ...

# %%
kospi_df_2023 =kospi_df[kospi_df['localDate']>='20230101']
kospi_df_2023['localDate']=pd.to_datetime(kospi_df_2023['localDate'])
kospi_df_2023
# Out:
# C:\Users\JeeYeon Kim\AppData\Local\Temp\ipykernel_11300\551161152.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kospi_df_2023['localDate']=pd.to_datetime(kospi_df_2023['localDate'])
#      localDate  closePrice  openPrice  highPrice  lowPrice  \
# 50  2023-01-02     2225.67    2249.95    2259.88   2222.37
# 51  2023-01-03     2218.68    2230.98    2230.98   2180.67
# 52  2023-01-04     2255.98    2205.98    2260.06   2198.82
# 53  2023-01-05     2264.65    2268.20    2281.39   2252.97
# 54  2023-01-06     2289.97    2253.40    2300.62   2253.27
# 55  2023-01-09     2350.19    2315.87    2351.06   2312.56
# 56  2023-01-10     2351.31    2348.04    2370.18   2344.18
# 57  2023-01-11     2359.53    2364.05    2369.66   2350.36
# ...

# %% [markdown]
# - 시각화

# %%
len(kospi_df_2023['localDate'])
# Out:
# 60

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(20,8))
plt.plot(kospi_df_2023['localDate'],kospi_df_2023['closePrice'],'r*:',label='kospi')
plt.plot(df_USD_2023['localDate'],df_USD_2023['closePrice'],'bo:',label='USD')
plt.plot(df_KOSDAQ_2023['localDate'],df_KOSDAQ_2023['closePrice'],'g^--',label='kosdaq')

plt.xticks(df_KOSDAQ_2023['localDate'],rotation=45,fontsize=7)
plt.legend()
plt.show()

# %%
 # 정규화 - scaling 
from sklearn.preprocessing import minmax_scale


plt.figure(figsize=(20,8))
plt.plot(kospi_df_2023['localDate'],minmax_scale(kospi_df_2023['closePrice']),'r*:',label='kospi')
plt.plot(df_USD_2023['localDate'],minmax_scale(df_USD_2023['closePrice']),'bo:',label='USD')
plt.plot(df_KOSDAQ_2023['localDate'],minmax_scale(df_KOSDAQ_2023['closePrice']),'g^--',label='kosdaq')

plt.xticks(df_KOSDAQ_2023['localDate'],rotation=45,fontsize=7)
plt.legend()
plt.show()

# %%
# 코스피, 코스닥, 미 달러 상관관계

import numpy as np

# 코스피,코스닥 상관관계
np.corrcoef(df_KOSDAQ_2023['closePrice'],kospi_df_2023['closePrice'])[0,1]
# Out:
# 0.6524673274316015

# %%
# 코스피,미 달러 상관관계
np.corrcoef(df_USD_2023['closePrice'],kospi_df_2023['closePrice'])[0,1]
# Out:
# 0.013958720952899814
